# %%
from IPython.display import clear_output
import ipywidgets as wdg
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import json
from uk_covid19 import Cov19API

# %%
# %matplotlib inline

plt.rcParams['figure.dpi'] = 100

# %%
def access_covid_api():
    filters=['areaType=overview']
    structure={"date":"date",
        "firstVac":"cumPeopleVaccinatedFirstDoseByPublishDate",
        "secondVac":"cumPeopleVaccinatedSecondDoseByPublishDate"}
    api=Cov19API(filters,structure)
    data=api.get_json()
    with open('vacTimes.json','wt') as OUTF:
        json.dump(data, OUTF)
    with open('vacTimes.json','rt') as INFILE:    
        vacData=json.load(INFILE)
    return vacData


vacData=access_covid_api()  #it works
vacData
# Out:
# {'data': [{'date': '2021-12-08', 'firstVac': 51183457, 'secondVac': 46640237},
#   {'date': '2021-12-07', 'firstVac': 51161757, 'secondVac': 46610800},
#   {'date': '2021-12-06', 'firstVac': 51138245, 'secondVac': 46582425},
#   {'date': '2021-12-05', 'firstVac': 51118266, 'secondVac': 46557413},
#   {'date': '2021-12-04', 'firstVac': 51096311, 'secondVac': 46530247},
#   {'date': '2021-12-03', 'firstVac': 51069397, 'secondVac': 46492449},
#   {'date': '2021-12-02', 'firstVac': 51046133, 'secondVac': 46462638},
#   {'date': '2021-12-01', 'firstVac': 51020285, 'secondVac': 46431662},
#   {'date': '2021-11-30', 'firstVac': 50994257, 'secondVac': 46399306},
#   {'date': '2021-11-29', 'firstVac': 50963718, 'secondVac': 46367149},
#   {'date': '2021-11-28', 'firstVac': 50941327, 'secondVac': 46341057},
#   {'date': '2021-11-27', 'firstVac': 50919834, 'secondVac': 46311612},
#   {'date': '2021-11-26', 'firstVac': 50896026, 'secondVac': 46278746},
#   {'date': '2021-11-25', 'firstVac': 50875712, 'secondVac': 46255081},
#   {'date': '2021-11-24', 'firstVac': 50852133, 'secondVac': 46232258},
#   {'date': '2021-11-23', 'firstVac': 50827554, 'secondVac': 46208819},
#   {'date': '2021-11-22', 'firstVac': 50800732, 'secondVac': 46186817},
#   {'date': '2021-11-21', 'firstVac': 50777474, 'secondVac': 46168300},
#   {'date': '2021-11-20', 'firstVac': 50761050, 'secondVac': 46154408},
#   {'date': '2021-11-19', 'firstVac': 50735037, 'secondVac': 46130215},
#   {'date': '2021-11-18', 'firstVac': 50707953, 'secondVac': 46108608},
#   {'date': '2021-11-17', 'firstVac': 50679073, 'secondVac': 46087958},
#   {'date': '2021-11-16', 'firstVac': 50645981, 'secondVac': 46065838},
#   {'date': '2021-11-15', 'firstVac': 50614550, 'secondVac': 46045964},
#   {'date': '2021-11-14', 'firstVac': 50582504, 'secondVac': 46027909},
#   {'date': '2021-11-13', 'firstVac': 50559566, 'secondVac': 46010861},
#   {'date': '2021-11-12', 'firstVac': 50526039, 'secondVac': 45986536},
#   {'date': '2021-11-11', 'firstVac': 50491701, 'secondVac': 45964488},
#   {'date': '2021-11-10', 'firstVac': 50455318, 'secondVac': 45942003},
#   {'date': '2021-11-09', 'firstVac': 50336130, 'secondVac': 45894237},
#   {'date': '2021-11-08', 'firstVac': 50296294, 'secondVac': 45873038},
#   {'date': '2021-11-07', 'firstVac': 50262735, 'secondVac': 45852677},
#   {'date': '2021-11-06', 'firstVac': 50236895, 'secondVac': 45838067},
#   {'date': '2021-11-05', 'firstVac': 50200147, 'secondVac': 45813567},
#   {'date': '2021-11-04', 'firstVac': 50156656, 'secondVac': 45790934},
#   {'date': '2021-11-03', 'firstVac': 50112925, 'secondVac': 45770452},
#   {'date': '2021-11-02', 'firstVac': 50071683, 'secondVac': 45752487},
#   {'date': '2021-11-01', 'firstVac': 50025020, 'secondVac': 45731565},
#   {'date': '2021-10-31', 'firstVac': 49987325, 'secondVac': 45712351},
#   {'date': '2021-10-30', 'firstVac': 49959923, 'secondVac': 45698902},
#   {'date': '2021-10-29', 'firstVac': 49923871, 'secondVac': 45673501},
#   {'date': '2021-10-28', 'firstVac': 49882904, 'secondVac': 45651222},
#   {'date': '2021-10-27', 'firstVac': 49838202, 'secondVac': 45627499},
#   {'date': '2021-10-26', 'firstVac': 49794120, 'secondVac': 45605922},
#   {'date': '2021-10-25', 'firstVac': 49753037, 'secondVac': 45582891},
#   {'date': '2021-10-24', 'firstVac': 49715228, 'secondVac': 45561445},
#   {'date': '2021-10-23', 'firstVac': 49689481, 'secondVac': 45543363},
#   {'date': '2021-10-22', 'firstVac': 49649389, 'secondVac': 45513120},
#   {'date': '2021-10-21', 'firstVac': 49603139, 'secondVac': 45486950},
#   {'date': '2021-10-20', 'firstVac': 49554407, 'secondVac': 45460122},
#   {'date': '2021-10-19', 'firstVac': 49505327, 'secondVac': 45433757},
#   {'date': '2021-10-18', 'firstVac': 49462425, 'secondVac': 45400990},
#   {'date': '2021-10-17', 'firstVac': 49422753, 'secondVac': 45377411},
#   {'date': '2021-10-16', 'firstVac': 49404916, 'secondVac': 45360146},
#   {'date': '2021-10-15', 'firstVac': 49375917, 'secondVac': 45326663},
#   {'date': '2021-10-14', 'firstVac': 49335154, 'secondVac': 45297231},
#   {'date': '2021-10-13', 'firstVac': 49291665, 'secondVac': 45269240},
#   {'date': '2021-10-12', 'firstVac': 49252939, 'secondVac': 45239759},
#   {'date': '2021-10-11', 'firstVac': 49216092, 'secondVac': 45212813},
#   {'date': '2021-10-10', 'firstVac': 49186920, 'secondVac': 45189181},
#   {'date': '2021-10-09', 'firstVac': 49164814, 'secondVac': 45169730},
#   {'date': '2021-10-08', 'firstVac': 49133419, 'secondVac': 45136253},
#   {'date': '2021-10-07', 'firstVac': 49101734, 'secondVac': 45107185},
#   {'date': '2021-10-06', 'firstVac': 49068705, 'secondVac': 45078529},
#   {'date': '2021-10-05', 'firstVac': 49035877, 'secondVac': 45049953},
#   {'date': '2021-10-04', 'firstVac': 48994530, 'secondVac': 45021381},
#   {'date': '2021-10-03', 'firstVac': 48956859, 'secondVac': 44992044},
#   {'date': '2021-10-02', 'firstVac': 48932736, 'secondVac': 44970512},
#   {'date': '2021-10-01', 'firstVac': 48901670, 'secondVac': 44936121},
#   {'date': '2021-09-30', 'firstVac': 48863490, 'secondVac': 44901832},
#   {'date': '2021-09-29', 'firstVac': 48829118, 'secondVac': 44867373},
#   {'date': '2021-09-28', 'firstVac': 48797579, 'secondVac': 44833280},
#   {'date': '2021-09-27', 'firstVac': 48765726, 'secondVac': 44799748},
#   {'date': '2021-09-26', 'firstVac': 48740807, 'secondVac': 44766571},
#   {'date': '2021-09-25', 'firstVac': 48724823, 'secondVac': 44741032},
#   {'date': '2021-09-24', 'firstVac': 48700527, 'secondVac': 44693914},
#   {'date': '2021-09-23', 'firstVac': 48672910, 'secondVac': 44649155},
#   {'date': '2021-09-22', 'firstVac': 48647827, 'secondVac': 44604567},
#   {'date': '2021-09-21', 'firstVac': 48625148, 'secondVac': 44560520},
#   {'date': '2021-09-20', 'firstVac': 48604764, 'secondVac': 44517114},
#   {'date': '2021-09-19', 'firstVac': 48584614, 'secondVac': 44470772},
#   {'date': '2021-09-18', 'firstVac': 48570774, 'secondVac': 44435615},
#   {'date': '2021-09-17', 'firstVac': 48544576, 'secondVac': 44363118},
#   {'date': '2021-09-16', 'firstVac': 48523798, 'secondVac': 44302734},
#   {'date': '2021-09-15', 'firstVac': 48500747, 'secondVac': 44238761},
#   {'date': '2021-09-14', 'firstVac': 48476345, 'secondVac': 44175471},
#   {'date': '2021-09-13', 'firstVac': 48458700, 'secondVac': 44108746},
#   {'date': '2021-09-12', 'firstVac': 48439272, 'secondVac': 44048093},
#   {'date': '2021-09-11', 'firstVac': 48424317, 'secondVac': 43995478},
#   {'date': '2021-09-10', 'firstVac': 48396404, 'secondVac': 43897419},
#   {'date': '2021-09-09', 'firstVac': 48370340, 'secondVac': 43805608},
#   {'date': '2021-09-08', 'firstVac': 48344566, 'secondVac': 43708906},
#   {'date': '2021-09-07', 'firstVac': 48319435, 'secondVac': 43620946},
#   {'date': '2021-09-06', 'firstVac': 48292811, 'secondVac': 43535098},
#   {'date': '2021-09-05', 'firstVac': 48270113, 'secondVac': 43455083},
#   {'date': '2021-09-04', 'firstVac': 48248318, 'secondVac': 43381890},
#   {'date': '2021-09-03', 'firstVac': 48207264, 'secondVac': 43253337},
#   {'date': '2021-09-02', 'firstVac': 48171998, 'secondVac': 43142747},
#   {'date': '2021-09-01', 'firstVac': 48131996, 'secondVac': 43023372},
#   {'date': '2021-08-31', 'firstVac': 48087908, 'secondVac': 42909987},
#   {'date': '2021-08-30', 'firstVac': 48048009, 'secondVac': 42790585},
#   {'date': '2021-08-29', 'firstVac': 48028366, 'secondVac': 42723937},
#   {'date': '2021-08-28', 'firstVac': 48003976, 'secondVac': 42644497},
#   {'date': '2021-08-27', 'firstVac': 47960705, 'secondVac': 42510809},
#   {'date': '2021-08-26', 'firstVac': 47915768, 'secondVac': 42379353},
#   {'date': '2021-08-25', 'firstVac': 47860628, 'secondVac': 42234417},
#   {'date': '2021-08-24', 'firstVac': 47792552, 'secondVac': 42072712},
#   {'date': '2021-08-23', 'firstVac': 47737142, 'secondVac': 41942036},
#   {'date': '2021-08-22', 'firstVac': 47690741, 'secondVac': 41810753},
#   {'date': '2021-08-21', 'firstVac': 47650396, 'secondVac': 41694401},
#   {'date': '2021-08-20', 'firstVac': 47577390, 'secondVac': 41499520},
#   {'date': '2021-08-19', 'firstVac': 47516505, 'secondVac': 41332128},
#   {'date': '2021-08-18', 'firstVac': 47460526, 'secondVac': 41157069},
#   {'date': '2021-08-17', 'firstVac': 47413242, 'secondVac': 40987846},
#   {'date': '2021-08-16', 'firstVac': 47369418, 'secondVac': 40841971},
#   {'date': '2021-08-15', 'firstVac': 47333702, 'secondVac': 40703581},
#   {'date': '2021-08-14', 'firstVac': 47302445, 'secondVac': 40577198},
#   {'date': '2021-08-13', 'firstVac': 47255842, 'secondVac': 40377614},
#   {'date': '2021-08-12', 'firstVac': 47215352, 'secondVac': 40206029},
#   {'date': '2021-08-11', 'firstVac': 47170968, 'secondVac': 40013470},
#   {'date': '2021-08-10', 'firstVac': 47129400, 'secondVac': 39839709},
#   {'date': '2021-08-09', 'firstVac': 47091889, 'secondVac': 39688566},
#   {'date': '2021-08-08', 'firstVac': 47059639, 'secondVac': 39551538},
#   {'date': '2021-08-07', 'firstVac': 47036796, 'secondVac': 39429468},
#   {'date': '2021-08-06', 'firstVac': 46998806, 'secondVac': 39215885},
#   {'date': '2021-08-05', 'firstVac': 46961830, 'secondVac': 39047529},
#   {'date': '2021-08-04', 'firstVac': 46926330, 'secondVac': 38874837},
#   {'date': '2021-08-03', 'firstVac': 46892996, 'secondVac': 38709168},
#   {'date': '2021-08-02', 'firstVac': 46863706, 'secondVac': 38566407},
#   {'date': '2021-08-01', 'firstVac': 46837614, 'secondVac': 38440215},
#   {'date': '2021-07-31', 'firstVac': 46816382, 'secondVac': 38322171},
#   {'date': '2021-07-30', 'firstVac': 46777556, 'secondVac': 38110157},
#   {'date': '2021-07-29', 'firstVac': 46740832, 'secondVac': 37939061},
#   {'date': '2021-07-28', 'firstVac': 46698479, 'secondVac': 37759143},
#   {'date': '2021-07-27', 'firstVac': 46654632, 'secondVac': 37587970},
#   {'date': '2021-07-26', 'firstVac': 46619230, 'secondVac': 37436320},
#   {'date': '2021-07-25', 'firstVac': 46589211, 'secondVac': 37287384},
#   {'date': '2021-07-24', 'firstVac': 46564660, 'secondVac': 37169428},
#   {'date': '2021-07-23', 'firstVac': 46520855, 'secondVac': 36965542},
#   {'date': '2021-07-22', 'firstVac': 46477881, 'secondVac': 36776201},
#   {'date': '2021-07-21', 'firstVac': 46433845, 'secondVac': 36587904},
#   {'date': '2021-07-20', 'firstVac': 46388744, 'secondVac': 36404566},
#   {'date': '2021-07-19', 'firstVac': 46349709, 'secondVac': 36243287},
#   {'date': '2021-07-18', 'firstVac': 46314039, 'secondVac': 36099727},
#   {'date': '2021-07-17', 'firstVac': 46295853, 'secondVac': 35970849},
#   {'date': '2021-07-16', 'firstVac': 46228636, 'secondVac': 35745635},
#   {'date': '2021-07-15', 'firstVac': 46159145, 'secondVac': 35543321},
#   {'date': '2021-07-14', 'firstVac': 46097464, 'secondVac': 35341428},
#   {'date': '2021-07-13', 'firstVac': 46037090, 'secondVac': 35155767},
#   {'date': '2021-07-12', 'firstVac': 45978017, 'secondVac': 34997491},
#   {'date': '2021-07-11', 'firstVac': 45923721, 'secondVac': 34872131},
#   {'date': '2021-07-10', 'firstVac': 45881721, 'secondVac': 34764511},
#   {'date': '2021-07-09', 'firstVac': 45787958, 'secondVac': 34553065},
#   {'date': '2021-07-08', 'firstVac': 45697875, 'secondVac': 34374246},
#   {'date': '2021-07-07', 'firstVac': 45601445, 'secondVac': 34198779},
#   {'date': '2021-07-06', 'firstVac': 45514492, 'secondVac': 34027302},
#   {'date': '2021-07-05', 'firstVac': 45428681, 'secondVac': 33874176},
#   {'date': '2021-07-04', 'firstVac': 45351719, 'secondVac': 33726362},
#   {'date': '2021-07-03', 'firstVac': 45274497, 'secondVac': 33614952},
#   {'date': '2021-07-02', 'firstVac': 45137108, 'secondVac': 33418743},
#   {'date': '2021-07-01', 'firstVac': 45013503, 'secondVac': 33241265},
#   {'date': '2021-06-30', 'firstVac': 44860978, 'secondVac': 33048199},
#   {'date': '2021-06-29', 'firstVac': 44719762, 'secondVac': 32872450},
#   {'date': '2021-06-28', 'firstVac': 44581771, 'secondVac': 32721762},
#   {'date': '2021-06-27', 'firstVac': 44454511, 'secondVac': 32583746},
#   {'date': '2021-06-26', 'firstVac': 44314799, 'secondVac': 32460191},
#   {'date': '2021-06-25', 'firstVac': 44080358, 'secondVac': 32260686},
#   {'date': '2021-06-24', 'firstVac': 43877861, 'secondVac': 32085916},
#   {'date': '2021-06-23', 'firstVac': 43656327, 'secondVac': 31908103},
#   {'date': '2021-06-22', 'firstVac': 43448680, 'secondVac': 31740115},
#   {'date': '2021-06-21', 'firstVac': 43148843, 'secondVac': 31489240},
#   {'date': '2021-06-20', 'firstVac': 43127763, 'secondVac': 31449915},
#   {'date': '2021-06-19', 'firstVac': 42964013, 'secondVac': 31340507},
#   {'date': '2021-06-18', 'firstVac': 42683772, 'secondVac': 31104144},
#   {'date': '2021-06-17', 'firstVac': 42460632, 'secondVac': 30898467},
#   {'date': '2021-06-16', 'firstVac': 42216654, 'secondVac': 30675207},
#   {'date': '2021-06-15', 'firstVac': 42021089, 'secondVac': 30440373},
#   {'date': '2021-06-14', 'firstVac': 41831056, 'secondVac': 30209707},
#   {'date': '2021-06-13', 'firstVac': 41698429, 'secondVac': 29973779},
#   {'date': '2021-06-12', 'firstVac': 41551201, 'secondVac': 29792658},
#   {'date': '2021-06-11', 'firstVac': 41297016, 'secondVac': 29472332},
#   {'date': '2021-06-10', 'firstVac': 41088485, 'secondVac': 29165140},
#   {'date': '2021-06-09', 'firstVac': 40886878, 'secondVac': 28857102},
#   {'date': '2021-06-08', 'firstVac': 40710319, 'secondVac': 28540844},
#   {'date': '2021-06-07', 'firstVac': 40573517, 'secondVac': 28227362},
#   {'date': '2021-06-06', 'firstVac': 40460576, 'secondVac': 27921294},
#   {'date': '2021-06-05', 'firstVac': 40333231, 'secondVac': 27661353},
#   {'date': '2021-06-04', 'firstVac': 40129618, 'secondVac': 27187975},
#   {'date': '2021-06-03', 'firstVac': 39949694, 'secondVac': 26799944},
#   {'date': '2021-06-02', 'firstVac': 39758428, 'secondVac': 26422303},
#   {'date': '2021-06-01', 'firstVac': 39585665, 'secondVac': 26073284},
#   {'date': '2021-05-31', 'firstVac': 39477158, 'secondVac': 25734719},
#   {'date': '2021-05-30', 'firstVac': 39384055, 'secondVac': 25539173},
#   {'date': '2021-05-29', 'firstVac': 39259168, 'secondVac': 25332851},
#   {'date': '2021-05-28', 'firstVac': 39075642, 'secondVac': 24914003},
#   {'date': '2021-05-27', 'firstVac': 38871200, 'secondVac': 24478052},
#   {'date': '2021-05-26', 'firstVac': 38614683, 'secondVac': 24043956},
#   {'date': '2021-05-25', 'firstVac': 38378564, 'secondVac': 23616498},
#   {'date': '2021-05-24', 'firstVac': 38192417, 'secondVac': 23228511},
#   {'date': '2021-05-23', 'firstVac': 38070038, 'secondVac': 22895556},
#   {'date': '2021-05-22', 'firstVac': 37943681, 'secondVac': 22643417},
#   {'date': '2021-05-21', 'firstVac': 37738271, 'secondVac': 22086466},
#   {'date': '2021-05-20', 'firstVac': 37518614, 'secondVac': 21659783},
#   {'date': '2021-05-19', 'firstVac': 37250363, 'secondVac': 21239471},
#   {'date': '2021-05-18', 'firstVac': 36985505, 'secondVac': 20870453},
#   {'date': '2021-05-17', 'firstVac': 36811405, 'secondVac': 20546452},
#   {'date': '2021-05-16', 'firstVac': 36704672, 'secondVac': 20287403},
#   {'date': '2021-05-15', 'firstVac': 36573354, 'secondVac': 20103658},
#   {'date': '2021-05-14', 'firstVac': 36336023, 'secondVac': 19712412},
#   {'date': '2021-05-13', 'firstVac': 36115955, 'secondVac': 19319010},
#   {'date': '2021-05-12', 'firstVac': 35906671, 'secondVac': 18890969},
#   {'date': '2021-05-11', 'firstVac': 35722461, 'secondVac': 18438532},
#   {'date': '2021-05-10', 'firstVac': 35587348, 'secondVac': 18088385},
#   {'date': '2021-05-09', 'firstVac': 35472295, 'secondVac': 17856550},
#   {'date': '2021-05-08', 'firstVac': 35371669, 'secondVac': 17669379},
#   {'date': '2021-05-07', 'firstVac': 35202642, 'secondVac': 17230542},
#   {'date': '2021-05-06', 'firstVac': 35069641, 'secondVac': 16764720},
#   {'date': '2021-05-05', 'firstVac': 34934171, 'secondVac': 16291719},
#   {'date': '2021-05-04', 'firstVac': 34795074, 'secondVac': 15887493},
#   {'date': '2021-05-03', 'firstVac': 34667904, 'secondVac': 15630007},
#   {'date': '2021-05-02', 'firstVac': 34595304, 'secondVac': 15502508},
#   {'date': '2021-05-01', 'firstVac': 34505380, 'secondVac': 15329617},
#   {'date': '2021-04-30', 'firstVac': 34362205, 'secondVac': 14957313},
#   {'date': '2021-04-29', 'firstVac': 34216616, 'secondVac': 14535528},
#   {'date': '2021-04-28', 'firstVac': 34094048, 'secondVac': 14043961},
#   {'date': '2021-04-27', 'firstVac': 33959908, 'secondVac': 13581076},
#   {'date': '2021-04-26', 'firstVac': 33843580, 'secondVac': 13201811},
#   {'date': '2021-04-25', 'firstVac': 33752885, 'secondVac': 12897123},
#   {'date': '2021-04-24', 'firstVac': 33673190, 'secondVac': 12636322},
#   {'date': '2021-04-23', 'firstVac': 33524423, 'secondVac': 12088686},
#   {'date': '2021-04-22', 'firstVac': 33388637, 'secondVac': 11623671},
#   {'date': '2021-04-21', 'firstVac': 33257651, 'secondVac': 11192601},
#   {'date': '2021-04-20', 'firstVac': 33139742, 'secondVac': 10775817},
#   {'date': '2021-04-19', 'firstVac': 33032120, 'secondVac': 10425790},
#   {'date': '2021-04-18', 'firstVac': 32932448, 'secondVac': 10152039},
#   {'date': '2021-04-17', 'firstVac': 32849223, 'secondVac': 9930846},
#   {'date': '2021-04-16', 'firstVac': 32709778, 'secondVac': 9431211},
#   {'date': '2021-04-15', 'firstVac': 32574221, 'secondVac': 8931547},
#   {'date': '2021-04-14', 'firstVac': 32444439, 'secondVac': 8513864},
#   {'date': '2021-04-13', 'firstVac': 32326604, 'secondVac': 8170081},
#   {'date': '2021-04-12', 'firstVac': 32250481, 'secondVac': 7857396},
#   {'date': '2021-04-11', 'firstVac': 32190576, 'secondVac': 7656205},
#   {'date': '2021-04-10', 'firstVac': 32121353, 'secondVac': 7466540},
#   {'date': '2021-04-09', 'firstVac': 32010244, 'secondVac': 6991310},
#   {'date': '2021-04-08', 'firstVac': 31903366, 'secondVac': 6541174},
#   {'date': '2021-04-07', 'firstVac': 31807124, 'secondVac': 6091905},
#   {'date': '2021-04-06', 'firstVac': 31707594, 'secondVac': 5683509},
#   {'date': '2021-04-05', 'firstVac': 31622367, 'secondVac': 5496716},
#   {'date': '2021-04-04', 'firstVac': 31581623, 'secondVac': 5432126},
#   {'date': '2021-04-03', 'firstVac': 31533568, 'secondVac': 5384418},
#   {'date': '2021-04-02', 'firstVac': 31425682, 'secondVac': 5205505},
#   {'date': '2021-04-01', 'firstVac': 31318262, 'secondVac': 4958874},
#   {'date': '2021-03-31', 'firstVac': 31147444, 'secondVac': 4513458},
#   {'date': '2021-03-30', 'firstVac': 30908010, 'secondVac': 4125884},
#   {'date': '2021-03-29', 'firstVac': 30682093, 'secondVac': 3848202},
#   {'date': '2021-03-28', 'firstVac': 30445284, 'secondVac': 3679972},
#   {'date': '2021-03-27', 'firstVac': 30151736, 'secondVac': 3532378},
#   {'date': '2021-03-26', 'firstVac': 29727435, 'secondVac': 3293517},
#   {'date': '2021-03-25', 'firstVac': 29316130, 'secondVac': 3009863},
#   {'date': '2021-03-24', 'firstVac': 28991188, 'secondVac': 2775481},
#   {'date': '2021-03-23', 'firstVac': 28653523, 'secondVac': 2532839},
#   {'date': '2021-03-22', 'firstVac': 28327873, 'secondVac': 2363684},
#   {'date': '2021-03-21', 'firstVac': 27997976, 'secondVac': 2281384},
#   {'date': '2021-03-20', 'firstVac': 27630970, 'secondVac': 2228772},
#   {'date': '2021-03-19', 'firstVac': 26878662, 'secondVac': 2136795},
#   {'date': '2021-03-18', 'firstVac': 26263732, 'secondVac': 2011070},
#   {'date': '2021-03-17', 'firstVac': 25735472, 'secondVac': 1879054},
#   {'date': '2021-03-16', 'firstVac': 25273226, 'secondVac': 1759445},
#   {'date': '2021-03-15', 'firstVac': 24839906, 'secondVac': 1663646},
#   {'date': '2021-03-14', 'firstVac': 24453221, 'secondVac': 1610280},
#   {'date': '2021-03-13', 'firstVac': 24196211, 'secondVac': 1584909},
#   {'date': '2021-03-12', 'firstVac': 23684103, 'secondVac': 1532754},
#   {'date': '2021-03-11', 'firstVac': 23314525, 'secondVac': 1445078},
#   {'date': '2021-03-10', 'firstVac': 23053716, 'secondVac': 1351515},
#   {'date': '2021-03-09', 'firstVac': 22809829, 'secondVac': 1254353},
#   {'date': '2021-03-08', 'firstVac': 22592528, 'secondVac': 1181431},
#   {'date': '2021-03-07', 'firstVac': 22377255, 'secondVac': 1142643},
#   {'date': '2021-03-06', 'firstVac': 22213112, 'secondVac': 1122402},
#   {'date': '2021-03-05', 'firstVac': 21796278, 'secondVac': 1090840},
#   {'date': '2021-03-04', 'firstVac': 21358815, 'secondVac': 1034068},
#   {'date': '2021-03-03', 'firstVac': 20982571, 'secondVac': 963862},
#   {'date': '2021-03-02', 'firstVac': 20703615, 'secondVac': 895412},
#   {'date': '2021-03-01', 'firstVac': 20478619, 'secondVac': 844098},
#   {'date': '2021-02-28', 'firstVac': 20275451, 'secondVac': 815816},
#   {'date': '2021-02-27', 'firstVac': 20089551, 'secondVac': 796132},
#   {'date': '2021-02-26', 'firstVac': 19682048, 'secondVac': 768810},
#   {'date': '2021-02-25', 'firstVac': 19177555, 'secondVac': 736037},
#   {'date': '2021-02-24', 'firstVac': 18691835, 'secondVac': 700718},
#   {'date': '2021-02-23', 'firstVac': 18242873, 'secondVac': 669105},
#   {'date': '2021-02-22', 'firstVac': 17916181, 'secondVac': 642788},
#   {'date': '2021-02-21', 'firstVac': 17723840, 'secondVac': 624325},
#   {'date': '2021-02-20', 'firstVac': 17582121, 'secondVac': 615148},
#   {'date': '2021-02-19', 'firstVac': 17247442, 'secondVac': 604885},
#   {'date': '2021-02-18', 'firstVac': 16875536, 'secondVac': 589591},
#   {'date': '2021-02-17', 'firstVac': 16423082, 'secondVac': 573724},
#   {'date': '2021-02-16', 'firstVac': 15940972, 'secondVac': 558577},
#   {'date': '2021-02-15', 'firstVac': 15576107, 'secondVac': 546165},
#   {'date': '2021-02-14', 'firstVac': 15300151, 'secondVac': 539630},
#   {'date': '2021-02-13', 'firstVac': 15062189, 'secondVac': 537715},
#   {'date': '2021-02-12', 'firstVac': 14556827, 'secondVac': 534869},
#   {'date': '2021-02-11', 'firstVac': 14012224, 'secondVac': 530094},
#   {'date': '2021-02-10', 'firstVac': 13509108, 'secondVac': 524447},
#   {'date': '2021-02-09', 'firstVac': 13058298, 'secondVac': 519553},
#   {'date': '2021-02-08', 'firstVac': 12646486, 'secondVac': 516392},
#   {'date': '2021-02-07', 'firstVac': 12294006, 'secondVac': 512581},
#   {'date': '2021-02-06', 'firstVac': 12015018, 'secondVac': 511719},
#   {'date': '2021-02-05', 'firstVac': 11465210, 'secondVac': 510057},
#   {'date': '2021-02-04', 'firstVac': 10971047, 'secondVac': 505993},
#   {'date': '2021-02-03', 'firstVac': 10490487, 'secondVac': 501957},
#   {'date': '2021-02-02', 'firstVac': 10021471, 'secondVac': 498962},
#   {'date': '2021-02-01', 'firstVac': 9646715, 'secondVac': 496796},
#   {'date': '2021-01-31', 'firstVac': 9296367, 'secondVac': 494209},
#   {'date': '2021-01-30', 'firstVac': 8977329, 'secondVac': 491053},
#   {'date': '2021-01-29', 'firstVac': 8378940, 'secondVac': 480432},
#   {'date': '2021-01-28', 'firstVac': 7891184, 'secondVac': 478254},
#   {'date': '2021-01-27', 'firstVac': 7476765, 'secondVac': 476485},
#   {'date': '2021-01-26', 'firstVac': 7164387, 'secondVac': 474156},
#   {'date': '2021-01-25', 'firstVac': 6853327, 'secondVac': 472446},
#   {'date': '2021-01-24', 'firstVac': 6573570, 'secondVac': 470478},
#   {'date': '2021-01-23', 'firstVac': 6353321, 'secondVac': 469660},
#   {'date': '2021-01-22', 'firstVac': 5861351, 'secondVac': 468617},
#   {'date': '2021-01-21', 'firstVac': 5383103, 'secondVac': 466796},
#   {'date': '2021-01-20', 'firstVac': 4973248, 'secondVac': 464036},
#   {'date': '2021-01-19', 'firstVac': 4609740, 'secondVac': 460625},
#   {'date': '2021-01-18', 'firstVac': 4266577, 'secondVac': 456866},
#   {'date': '2021-01-17', 'firstVac': 4062501, 'secondVac': 452301},
#   {'date': '2021-01-16', 'firstVac': 3872394, 'secondVac': 450062},
#   {'date': '2021-01-15', 'firstVac': 3576263, 'secondVac': 447442},
#   {'date': '2021-01-14', 'firstVac': 3234946, 'secondVac': 443234},
#   {'date': '2021-01-13', 'firstVac': 2918252, 'secondVac': 437977},
#   {'date': '2021-01-12', 'firstVac': 2639309, 'secondVac': 428232},
#   {'date': '2021-01-11', 'firstVac': 2431648, 'secondVac': 412167},
#   {'date': '2021-01-10', 'firstVac': 2286572, 'secondVac': 391399}],
#  'lastUpdate': '2021-12-09T16:00:01.000000Z',
#  'length': 333,
#  'totalPages': 1}

# %%
def parse_date(date_string):
    return pd.to_datetime(date_string,format="%Y-%m-%d")
def wrangle_data(olddata):
    datalist=olddata['data']
    dates=[dictionary['date'] for dictionary in datalist]
    dates.sort()
    startdate=parse_date(dates[0])
    enddate=parse_date(dates[-1])
    index=pd.date_range(startdate,enddate,freq='D')
    vacTimesdf=pd.DataFrame(index=index,columns=['firstVac','secondVac'])
    for line in datalist:
        data=parse_date(line['date'])
        for column in ['firstVac','secondVac']:
            value=float(line[column] if line[column] !=None else 0.0)
            vacTimesdf.loc[data,column]=value
            
    vacTimesdf.fillna(0.0,inplace=True)
    return vacTimesdf

vacTimesdf=wrangle_data(vacData)

# %%
vac_clos=wdg.SelectMultiple(
    options=['firstVac','secondVac'],
    value=['firstVac','secondVac'],
    rows=3,
    description='Vaccinated:',
    disabled=False)

scale=wdg.RadioButtons(
    options=['linear', 'log'],
#    value='pineapple', # Defaults to 'pineapple'
#    layout={'width': 'max-content'}, # If the items' names are long
    description='Scale:',
    disabled=False
)

# try replacing HBox with a VBox
controls=wdg.VBox([vac_clos, scale])
#plt.ticklabel_format(style='plain')
def vac_graph(gcols, gscale):
    if gscale=='linear':
        logscale=False
    else:
        logscale=True
    ncols=len(gcols)
    if ncols>0:
        vacTimesdf[list(gcols)].plot(logy=logscale)
        plt.show() # important - graphs won't update if this is missing 
    else:
        print("Click to select data for graph")
        print("(CTRL-Click to select more than one category)")

# keep calling timeseries_graph(gcols=value_of_series, gscale=value_of_scale); 
# capture output in widget graph   
graph=wdg.interactive_output(vac_graph, {'gcols': vac_clos, 'gscale': scale})

display(controls, graph)
# Out:
# VBox(children=(SelectMultiple(description='Vaccinated:', index=(0, 1), options=('firstVac', 'secondVac'), rows…
# Output()

# %%
def api_button_callback(button):
    """ Button callback - it must take the button as its parameter (unused in this case).
    Accesses API, wrangles data, updates global variable df used for plotting. """
    # Get fresh data from the API. If you have time, include some error handling
    # around this call.
    vacData=access_covid_api(filters,structure)
    # wrangle the data and overwrite the dataframe for plotting
    global vacTimesdf
    vacTimesdf=wrangle_data(vacData)
    # the graph won't refresh until the user interacts with the widget.
    # this function simulates the interaction, see Graph and Analysis below.
    # you can omit this step in the first instance
    #refresh_graph()
    # after all is done, you can switch the icon on the button to a "check" sign
    # and optionally disable the button - it won't be needed again. You can use icons
    # "unlink" or "times" and change the button text to "Unavailable" in case the 
    # api call fails.
    apibutton.icon="check"
    # apibutton.disabled=True

    
apibutton=wdg.Button(
    description='PANIC', # you may want to change this...
    disabled=False,
    button_style='danger', # 'success', 'info', 'warning', 'danger' or ''
    tooltip="Keep calm and carry on",
    # FontAwesome names without the `fa-` prefix - try "download"
    icon='exclamation-triangle'
)

# remember to register your button callback function with the button
apibutton.on_click(api_button_callback) # the name of your function inside these brackets

display(apibutton)
# Out:
# Button(button_style='danger', description='PANIC', icon='exclamation-triangle', style=ButtonStyle(), tooltip='…
